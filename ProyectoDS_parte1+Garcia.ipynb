# %% [markdown]
# ***Análisis de emisiones principales de Co2 en el mundo***
#
# Autor: Agustín García
#
# Institución: Coder House

# %% [markdown]
# ***Introducción***
#
# Para el presente trabajo se extrajo información de emisiones de Co2 a nivel mundial.
#
# Estos datos fueron extraídos de Kaggle. El Dataset presente consiste en emisiones de Co2 en medida (metricon) per cápita por caída país alrededor del mundo. Estos datos fueron recolectados a través desde World Data Bank.
#
# Links:
#
# https://data.worldbank.org/indicator/EN.ATM.CO2E.PC
#
# https://www.kaggle.com/datasets/koustavghosh149/co2-emission-around-the-world

# %% [markdown]
# ***Hipótesis***
#
# Se analizaran y se realizaran graficas a fin de que nos briden información fidedigna y valiosa,
# para de esta manera poder respondernos; si las emisiones de Co2 han disminuido con el paso del
# tiempo hasta nuestros días, y cuáles son los piases donde hay una mayor tendencia a lo largo del tiempo
# a tener mayores niveles de contaminación.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/Users/user/Downloads/SegundaEntregaCoder/GCB2022v27_MtCO2_flat.csv')

# %%
paises=list(df.groupby('Country').sum().sort_values(by='Total', ascending=False).index)

# %%
valores=list(df.groupby('Country').sum().sort_values(by='Total', ascending=False)['Total'])

# %%
plt.figure(figsize=(10,10))

# %%
sns.set_style('ticks')

# %%
sns.barplot(x=paises[:6],y= valores[:6])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***RESUMEN NUMERICO***
# # En la siguiente grafica podemos apreciar en el Eje (Y) numeros los cuales representan la proporcion con respecto a los paises que aparecen graficados en el Eje (X), lo cual nos indica el pais con mayor predominacion en contaminacion por Co2

# %%
df['Total'].describe()
# Out:
# count    62904.000000
# mean        55.224788
# std        824.845435
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.549342
# max      37123.850352
# Name: Total, dtype: float64

# %%
usa = df[df['Country']=='USA']
USA_data = usa[-35:]
plt.figure(figsize=(15,5))
sns.barplot(x='Year',y='Total',data=USA_data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total'>

# %% [markdown]
# ***RESUMEN NUMERICO***
# # En la siguiente grafica podemos apreciar en el eje (Y) los valores de contaminacion (metricon) per capita y en el eje (X) podemos observar un grafico de barras el cual nos expone la suba o baja de contaminacion en el periodo de años (2007-2021) para el pais de Estados Unidos

# %%
china = df[df['Country']=='China']
China_data = china[-35:]
plt.figure(figsize=(15,5))
sns.barplot(x='Year',y='Total',data=China_data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total'>

# %% [markdown]
# ***RESUMEN NUMERICO***
# # En la siguiente grafica podemos apreciar en el eje (Y) los valores de contaminacion (metricon) per capita y en el eje (X) podemos observar un grafico de barras el cual nos expone la suba o baja de contaminacion en el periodo de años (2007-2021) para el pais de China

# %%
russia = df[df['Country']=='Russia']
Russia_data = russia[-35:]
plt.figure(figsize=(15,5))
sns.barplot(x='Year',y='Total',data=Russia_data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total'>

# %% [markdown]
# ***RESUMEN NUMERICO***
# # En la siguiente grafica podemos apreciar en el eje (Y) los valores de contaminacion (metricon) per capita y en el eje (X) podemos observar un grafico de barras el cual nos expone la suba o baja de contaminacion en el periodo de años (2007-2021) para el pais de Russia

# %%
germany = df[df['Country']=='Germany']
Germany_data = germany[-35:]
plt.figure(figsize=(15,5))
sns.barplot(x='Year',y='Total',data=Germany_data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total'>

# %% [markdown]
# ***RESUMEN NUMERICO***
# # En la siguiente grafica podemos apreciar en el eje (Y) los valores de contaminacion (metricon) per capita y en el eje (X) podemos observar un grafico de barras el cual nos expone la suba o baja de contaminacion en el periodo de años (2007-2021) para el pais de Alemania

# %%
unitedKingdom = df[df['Country']=='United Kingdom']
unitedKingdom_data = unitedKingdom[-35:]
plt.figure(figsize=(15,5))
sns.barplot(x='Year', y='Total', data=unitedKingdom_data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total'>

# %% [markdown]
# ***RESUMEN NUMERICO***
# # En la siguiente grafica podemos apreciar en el eje (Y) los valores de contaminacion (metricon) per capita y en el eje (X) podemos observar un grafico de barras el cual nos expone la suba o baja de contaminacion en el periodo de años (2007-2021) para los paises de Reino Unido

# %%
sns.lineplot(x='Year',y='Total',data=USA_data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total'>

# %% [markdown]
# ###RESUMEN NUMERICO###
# # En la siguiente grafica podemos observar en el Eje (Y) los valores de contaminacion por Co2 y en el Eje (X) los valores de los años. En esta grafica lineal podemos entender que la contaminacion por Co2 en Estados Unidos a disminuido signficativamente desde el año 1987 al año 2021. Se osbseva una tendencia ascendente desde el año 1987 al año 2005 donde alcanza su pico con un valor aproximado a los 6180 (metricon), luego se observa una caida de los valores alcanzado un punto minimo en el año 2020 con un valor aproximado a los 4000 (metricon).

# %%
sns.lineplot(x='Year',y='Total',data=China_data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total'>

# %% [markdown]
# ###RESUMEN NUMERICO###
# # En la siguiente grafica podemos observar en el Eje (Y) los valores de contaminacion por Co2 y en el Eje (X) los valores de los años. En esta grafica lineal podemos entender que la contaminacion por Co2 en China a aumentado signficativamente, presentado una tendencia ascendente desde el año 1987 al año 2020 pasando el valor de los 10000 (metricon)

# %%
sns.lineplot(x='Year',y='Total',data=Russia_data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total'>

# %% [markdown]
# ###RESUMEN NUMERICO###
# # En la siguiente grafica podemos observar en el Eje (Y) los valores de contaminacion por Co2 y en el Eje (X) los valores de los años. En esta grafica lineal podemos entender que la contaminacion por Co2 en Russia a tenido su pico en el año 1992 aproximadamente, luego disminuye significativamente hacia el año 1996 presentando subidas y bajadas para finalmente en el año 2020 presenta una pequeño ascenso hacia los 1800 (metricon)

# %%
sns.lineplot(x='Year',y='Total',data=Germany_data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total'>

# %% [markdown]
# ###RESUMEN NUMERICO###
# # En la siguiente grafica podemos observar en el Eje (Y) los valores de contaminacion por Co2 y en el Eje (X) los valores de los años. En esta grafica lineal podemos entender que la contaminacion por Co2 en Alemania tiene un pico inicial aproximado a los 1500 (metricon) en el año 1991, luego se observa un descenso significativo hacia el año 2020 donde se observa un valor aproximado a los 500 (metricon), donde hacia el final de la grafica podemos distinguir una leve subida

# %%
sns.lineplot(x='Year',y='Total',data=unitedKingdom_data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total'>

# %% [markdown]
# ###RESUMEN NUMERICO###
# # En la siguiente grafica podemos observar en el Eje (Y) los valores de contaminacion por Co2 y en el Eje (Y) los valores de los años. En esta grafica lineal podemos entender que la contaminacion por Co2 en Reino Unido tiene su pico en el año 1992 pasado apenas los 600 (metricon), luego se observa una tendencia descendente que llega hacia el año 2020 tocando su punto mas bajo de 200 (metricon) aproximadamente, luego se observa una leve tendencia ascendente
