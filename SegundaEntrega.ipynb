# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='/Users/user/Downloads/SegundaEntregaCoder/GCB2022v27_MtCO2_flat.csv'
df=pd.read_csv('/Users/user/Downloads/SegundaEntregaCoder/GCB2022v27_MtCO2_flat.csv')
print((df).head(5))
# Out:
#        Country ISO 3166-1 alpha-3  Year  Total  Coal  Oil  Gas  Cement  \
# 0  Afghanistan                AFG  1750    0.0   NaN  NaN  NaN     NaN
# 1  Afghanistan                AFG  1751    0.0   NaN  NaN  NaN     NaN
# 2  Afghanistan                AFG  1752    0.0   NaN  NaN  NaN     NaN
# 3  Afghanistan                AFG  1753    0.0   NaN  NaN  NaN     NaN
# 4  Afghanistan                AFG  1754    0.0   NaN  NaN  NaN     NaN
#
#    Flaring  Other  Per Capita
# 0      NaN    NaN         NaN
# 1      NaN    NaN         NaN
# 2      NaN    NaN         NaN
# 3      NaN    NaN         NaN
# 4      NaN    NaN         NaN

# %%
df.shape
# Out:
# (63104, 11)

# %% [markdown]
# ***GRAFICO EL TOTAL POR CONTAMINACION DE COBALTO***

# %%
df.plot(x='Total' , y='Coal' )
plt.show()

# %% [markdown]
# ***GRAFICO EL TOTAL POR CONTAMINACION DE COMBUSTIBLE***

# %%
df.plot(x='Total' , y='Oil', )
plt.show()

# %% [markdown]
# ***GRAFICO EL TOTAL POR CONTAMINACION DE GASES***

# %%
df.plot(x='Total' , y='Gas')
plt.show()
