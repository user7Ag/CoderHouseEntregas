# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import openaq
import warnings
import numpy as np
import statsmodels.api as sm
import sklearn
sklearn.__version__

warnings.simplefilter('ignore')

# %matplotlib inline

# Set major seaborn asthetics
sns.set("notebook", style='ticks', font_scale=1.0)

# Increase the quality of inline plots
mpl.rcParams['figure.dpi']= 500

print ("pandas v{}".format(pd.__version__))
print ("matplotlib v{}".format(mpl.__version__))
print ("seaborn v{}".format(sns.__version__))
print ("openaq v{}".format(openaq.__version__))
# Out:
# pandas v1.4.4
# matplotlib v3.5.2
# seaborn v0.12.2
# openaq v1.1.0

# %% [markdown]
# ***FIRST REQUEST***

# %%
api = openaq.OpenAQ()

# %% [markdown]
# ***CITIES***

# %% [markdown]
# El endpoint API de cities lista las ciudades disponibles dentro de la plataforma. Los resultados pueden ser subseleccionados por país y paginados para recuperar todos los resultados en la base de datos. Comencemos realizando una consulta básica con un límite aumentado (para que podamos obtener todas las ciudades) y devolverlo como un DataFrame:

# %%
resp = api.cities(df=True, limit=10000)

# %% [markdown]
# ***DATACRAWLING API CITITES***

# %%
resp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    3276 non-null   object
#  1   name       3276 non-null   object
#  2   city       3276 non-null   object
#  3   count      3276 non-null   int64
#  4   locations  3276 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 128.1+ KB

# %%
resp=resp.dropna()

# %%
resp.isna().any()
# Out:
# country      False
# name         False
# city         False
# count        False
# locations    False
# dtype: bool

# %%
resp.isna().sum()
# Out:
# country      0
# name         0
# city         0
# count        0
# locations    0
# dtype: int64

# %%
print (resp.head(10))
# Out:
#   country       name       city  count  locations
# 0      US        007        007  55743          7
# 1      US        019        019   2112          1
# 2      US        037        037  48525         23
# 3      US        039        039   1140          1
# 4      US        047        047  47331          4
# 5      US        051        051    990          7
# 6      US        077        077   9982          1
# 7      CH     Aargau     Aargau  12162          1
# 8      MX    Abasolo    Abasolo   1095          1
# 9      US  ABBEVILLE  ABBEVILLE   4619          1

# %%
print (resp.query("country == 'IN'"))
# Out:
#      country           name           city    count  locations
# 28        IN       Agartala       Agartala   212295          4
# 29        IN           Agra           Agra  1290629         10
# 32        IN      Ahmedabad      Ahmedabad  1516674         18
# 41        IN         Aizawl         Aizawl   239586          2
# 42        IN          Ajmer          Ajmer   831131          4
# ...      ...            ...            ...      ...        ...
# 2656      IN  Visakhapatnam  Visakhapatnam  1133283          9
# 2667      IN      Vrindavan      Vrindavan   118368          3
# 2749      IN         Yadgir         Yadgir   329778          2
# 2756      IN    Yamunanagar    Yamunanagar       18          1
# 2757      IN   Yamuna Nagar   Yamuna Nagar   536475          1
#
# [200 rows x 5 columns]

# %% [markdown]
# ***COUNTRIES***

# %% [markdown]
# Similar al endpoint de ciudades, el endpoint de países lista los países disponibles. Los únicos parámetros con los que contamos son el límite y el número de página. Si queremos obtenerlos todos, podemos simplemente aumentar el límite al máximo (10000).

# %%
res = api.countries(limit=10000, df=True)

print (res.head())
# Out:
#   code     count  locations  cities                  name
# 0   AD    726810          3       2               Andorra
# 1   AE  23351954         32       9  United Arab Emirates
# 2   AF   3148590          3       2           Afghanistan
# 3   AG     94563          1       1                    AG
# 4   AJ     11668         10       1                    AJ

# %% [markdown]
# ***DATA CRAWLING API COUNTRIES***

# %%
res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   code       159 non-null    object
#  1   count      159 non-null    int64
#  2   locations  159 non-null    int64
#  3   cities     159 non-null    int64
#  4   name       159 non-null    object
# dtypes: int64(3), object(2)
# memory usage: 6.3+ KB

# %%
res=res.dropna()

# %%
res.isna().any()
# Out:
# code         False
# count        False
# locations    False
# cities       False
# name         False
# dtype: bool

# %%
res.isna().sum()
# Out:
# code         0
# count        0
# locations    0
# cities       0
# name         0
# dtype: int64

# %% [markdown]
# ***PARAMETERS***

# %% [markdown]
# El endpoint de parámetros proporcionará un listado de todos los parámetros disponibles:

# %%
res = api.parameters(df=True)

print (res)
# Out:
#        id   name                                        description  \
# 0       1   pm10  Particulate matter less than 10 micrometers in...
# 1       2   pm25  Particulate matter less than 2.5 micrometers i...
# 2       3     o3                           Ozone mass concentration
# 3       4     co                 Carbon Monoxide mass concentration
# 4       5    no2                Nitrogen Dioxide mass concentration
# 5       6    so2                  Sulfur Dioxide mass concentration
# 6       7    no2                     Nitrogen Dioxide concentration
# 7       8     co                      Carbon Monoxide concentration
# 8       9    so2                       Sulfur Dioxide concentration
# 9      10     o3                                Ozone concentration
# 10     11     bc                    Black Carbon mass concentration
# 11     19    pm1  Particulate matter less than 1 micrometer in d...
# 12     21    co2                       Carbon Dioxide concentration
# 13     27    nox                 Nitrogen Oxides mass concentration
# 14     28    ch4                              Methane concentration
# 15     33    ufp            Ultrafine Particles count concentration
# 16     35     no                    Nitrogen Monoxide concentration
# 17    126  um010                                          PM1 count
# 18    130  um025                                        PM2.5 count
# 19    135  um100                                         PM10 count
# 20  19840    nox                      Nitrogen Oxides concentration
# 21  19843     no               Nitrogen Monoxide mass concentration
# 22  19844    pm4  Particulate matter less than 4 micrometers in ...
#
#     preferredUnit
# 0           µg/m³
# 1           µg/m³
# 2           µg/m³
# 3           µg/m³
# 4           µg/m³
# 5           µg/m³
# 6             ppm
# 7             ppm
# 8             ppm
# 9             ppm
# 10          µg/m³
# 11          µg/m³
# 12            ppm
# 13          µg/m³
# 14            ppm
# 15  particles/cm³
# 16            ppm
# 17  particles/cm³
# 18  particles/cm³
# 19  particles/cm³
# 20            ppm
# 21          µg/m³
# 22          µg/m³

# %% [markdown]
# ***DATA CRAWLING API PARAMETERS***

# %%
res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             23 non-null     int64
#  1   name           23 non-null     object
#  2   description    23 non-null     object
#  3   preferredUnit  23 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 864.0+ bytes

# %%
res=res.dropna()

# %%
res.isna().any()
# Out:
# id               False
# name             False
# description      False
# preferredUnit    False
# dtype: bool

# %%
res.isna().sum()
# Out:
# id               0
# name             0
# description      0
# preferredUnit    0
# dtype: int64

# %% [markdown]
# ***SOURCES***

# %% [markdown]
# El endpoint de sources proporcionará una lista de las fuentes de donde provino la información cruda.

# %%
res = api.sources(df=True)

# Print out the first one
print (res)
# Out:
#                                                   url      adapter  \
# 0   http://agaar.mn/aqdata/stationlist?period=h&la...     agaar_mn
# 1                        http://files.airnowtech.org/  airnow-http
# 2                                   ftp.airnowapi.org   airnow-ftp
# 3   http://www.dpccairdata.com/dpccairdata/display...        india
# 4   http://www.juntadeandalucia.es/medioambiente/s...    andalucia
# ..                                                ...          ...
# 95  http://dosairnowdata.org/dos/RSS/Accra/Accra-P...     stateair
# 96  http://dosairnowdata.org/dos/RSS/AddisAbabaCen...     stateair
# 97  http://dosairnowdata.org/dos/RSS/AddisAbabaSch...     stateair
# 98  http://dosairnowdata.org/dos/RSS/Algiers/Algie...     stateair
# 99  http://dosairnowdata.org/dos/RSS/Amman/Amman-P...     stateair
#
#                             name         city country  \
# 0                       Agaar.mn  Ulaanbaatar      MN
# 1                         AirNow
# 2                     AirNow FTP
# 3                    Anand Vihar        Delhi      IN
# 4                      Andalucia         None      ES
# ..                           ...          ...     ...
# 95                StateAir_Accra        Accra      GH
# 96  StateAir_Addis_Ababa_Central  Addis Ababa      ET
# 97   StateAir_Addis_Ababa_School  Addis Ababa      ET
# 98              StateAir_Algiers      Algiers      DZ
# 99                StateAir_Amman        Amman      JO
#
#                                           description  \
# 0
# 1       AirNow adapter using files streamed over http
# 2
# 3
# 4   Data for Andalucia from its Ministry of Enviro...
# ..                                                ...
# 95
# 96
# 97
# 98
# 99
#
#                                             sourceURL resolution  \
# 0                               http://agaar.mn/index       1 hr
# 1                              http://www.airnow.gov/       None
# 2                              http://www.airnow.gov/       None
# 3   http://www.dpccairdata.com/dpccairdata/display...     15 min
# 4   http://www.juntadeandalucia.es/medioambiente/a...       None
# ..                                                ...        ...
# 95  http://dosairnowdata.org/dos/RSS/Accra/Accra-P...       None
# 96                                https://airnow.gov/       None
# 97                                https://airnow.gov/       None
# 98                           http://stateair.net/dos/       None
# 99                           http://stateair.net/dos/       None
#
#              contacts  active
# 0   [info@openaq.org]   False
# 1   [info@openaq.org]    True
# 2   [info@openaq.org]   False
# 3   [info@openaq.org]   False
# 4   [info@openaq.org]    True
# ..                ...     ...
# 95  [info@openaq.org]    True
# 96  [info@openaq.org]    True
# 97  [info@openaq.org]    True
# 98  [info@openaq.org]    True
# 99  [info@openaq.org]    True
#
# [100 rows x 10 columns]

# %% [markdown]
# ***DATA CRAWLING SOURCES***

# %%
res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   url          100 non-null    object
#  1   adapter      100 non-null    object
#  2   name         100 non-null    object
#  3   city         89 non-null     object
#  4   country      100 non-null    object
#  5   description  99 non-null     object
#  6   sourceURL    100 non-null    object
#  7   resolution   37 non-null     object
#  8   contacts     100 non-null    object
#  9   active       100 non-null    bool
# dtypes: bool(1), object(9)
# memory usage: 7.3+ KB

# %%
res=res.dropna()

# %%
res.isna().any()
# Out:
# url            False
# adapter        False
# name           False
# city           False
# country        False
# description    False
# sourceURL      False
# resolution     False
# contacts       False
# active         False
# dtype: bool

# %%
res.isna().sum()
# Out:
# url            0
# adapter        0
# name           0
# city           0
# country        0
# description    0
# sourceURL      0
# resolution     0
# contacts       0
# active         0
# dtype: int64

# %% [markdown]
# ***LATEST***

# %% [markdown]
# Obtiene los datos más recientes de una o varias ubicaciones.
#
# En este caso en la talba siguiente a esta probamos la misma ¿Cuál fue el valor más reciente de PM2.5 en Delhi?

# %%
res = api.latest(city='Hilo', parameter='so2', df=True)

res
# Out:
#                           parameter  value                    unit sourceName  \
# lastUpdated
# 2023-03-26 04:00:00+00:00       so2  0.000                     ppm     AirNow
# 2023-03-26 04:00:00+00:00      pm25  8.000  b'\xc2\xb5g/m\xc2\xb3'     AirNow
# 2023-03-26 04:00:00+00:00       so2  0.000                     ppm     AirNow
# 2023-03-26 04:00:00+00:00       so2  0.000                     ppm     AirNow
# 2023-03-26 04:00:00+00:00      pm25  4.000  b'\xc2\xb5g/m\xc2\xb3'     AirNow
# 2023-03-26 04:00:00+00:00      pm25  0.000  b'\xc2\xb5g/m\xc2\xb3'     AirNow
# 2023-03-26 04:00:00+00:00       so2  0.000                     ppm     AirNow
# 2023-03-26 04:00:00+00:00       so2  0.001                     ppm     AirNow
# 2023-03-26 04:00:00+00:00      pm25  2.000  b'\xc2\xb5g/m\xc2\xb3'     AirNow
# 2018-07-02 20:00:00+00:00       so2  0.178                     ppm     AirNow
# 2018-06-21 23:00:00+00:00       so2  0.000                     ppm     AirNow
# 2017-01-26 17:00:00+00:00       so2  0.002                     ppm     AirNow
#
#                           country  city             location  \
# lastUpdated
# 2023-03-26 04:00:00+00:00      US  Hilo  Hawaii Volcanoes NP
# 2023-03-26 04:00:00+00:00      US  Hilo               Pahala
# 2023-03-26 04:00:00+00:00      US  Hilo               Pahala
# 2023-03-26 04:00:00+00:00      US  Hilo                 Kona
# 2023-03-26 04:00:00+00:00      US  Hilo                 Kona
# 2023-03-26 04:00:00+00:00      US  Hilo                 Hilo
# 2023-03-26 04:00:00+00:00      US  Hilo                 Hilo
# 2023-03-26 04:00:00+00:00      US  Hilo           Ocean View
# 2023-03-26 04:00:00+00:00      US  Hilo           Ocean View
# 2018-07-02 20:00:00+00:00      US  Hilo  Hawaii Volcanoes NP
# 2018-06-21 23:00:00+00:00      US  Hilo        Mountain View
# 2017-01-26 17:00:00+00:00      US  Hilo       Puna E Station
#
#                            averagingPeriod.value averagingPeriod.unit
# lastUpdated
# 2023-03-26 04:00:00+00:00                   3600              seconds
# 2023-03-26 04:00:00+00:00                   3600              seconds
# 2023-03-26 04:00:00+00:00                   3600              seconds
# 2023-03-26 04:00:00+00:00                   3600              seconds
# 2023-03-26 04:00:00+00:00                   3600              seconds
# 2023-03-26 04:00:00+00:00                   3600              seconds
# 2023-03-26 04:00:00+00:00                   3600              seconds
# 2023-03-26 04:00:00+00:00                   3600              seconds
# 2023-03-26 04:00:00+00:00                   3600              seconds
# 2018-07-02 20:00:00+00:00                   3600              seconds
# 2018-06-21 23:00:00+00:00                   3600              seconds
# 2017-01-26 17:00:00+00:00                   3600              seconds

# %% [markdown]
# ***DATA CRAWLING LATEST***

# %%
res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 2023-03-26 04:00:00+00:00 to 2017-01-26 17:00:00+00:00
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   parameter              12 non-null     object
#  1   value                  12 non-null     float64
#  2   unit                   12 non-null     object
#  3   sourceName             12 non-null     object
#  4   country                12 non-null     object
#  5   city                   12 non-null     object
#  6   location               12 non-null     object
#  7   averagingPeriod.value  12 non-null     int64
#  8   averagingPeriod.unit   12 non-null     object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 960.0+ bytes

# %%
res=res.dropna()

# %%
res.isna().any()
# Out:
# parameter                False
# value                    False
# unit                     False
# sourceName               False
# country                  False
# city                     False
# location                 False
# averagingPeriod.value    False
# averagingPeriod.unit     False
# dtype: bool

# %%
res.isna().sum()
# Out:
# parameter                0
# value                    0
# unit                     0
# sourceName               0
# country                  0
# city                     0
# location                 0
# averagingPeriod.value    0
# averagingPeriod.unit     0
# dtype: int64

# %% [markdown]
# ***MEASUREMENTS***

# %% [markdown]
# Finalmente, ¡el endpoint que todos hemos estado esperando! Measurements te permite obtener ¡todos los datos! Puedes consultar sobre una gran cantidad de parámetros que se encuentran listados en la documentación de la API. Vamos a sumergirnos:
#
# Obtengamos los últimos 10000 puntos de datos para PM2.5 en Delhi:

# %%
res = api.measurements(city='Delhi', parameter='pm25', limit=10000, df=True)

# Print out the statistics on a per-location basiss
res.groupby(['location'])['value'].describe()
# Out:
#                                                    count        mean  \
# location
# Alipur, Delhi - DPCC                               233.0   57.107296
# Anand Vihar, Delhi - DPCC                            1.0  283.000000
# Ashok Vihar, Delhi - DPCC                          365.0   54.131507
# Aya Nagar, Delhi - IMD                             160.0   37.006188
# Bawana, Delhi - DPCC                               286.0   53.877622
# CRRI Mathura Road, Delhi - IMD                     122.0   50.537623
# DTU, Delhi - CPCB                                  425.0   42.849412
# Dr. Karni Singh Shooting Range, Delhi - DPCC         2.0  154.500000
# Dwarka-Sector 8, Delhi - DPCC                      382.0   53.188482
# IGI Airport (T3), Delhi - IMD                      244.0   48.230738
# IHBAS, Dilshad Garden, Delhi - CPCB                305.0   60.798033
# ITO, Delhi - CPCB                                  411.0   67.447689
# Jahangirpuri, Delhi - DPCC                         185.0   64.659459
# Jawaharlal Nehru Stadium, Delhi - DPCC             273.0   49.538462
# Lodhi Road, Delhi - IMD                            123.0   43.804309
# Major Dhyan Chand National Stadium, Delhi - DPCC   356.0   53.918539
# Mandir Marg, Delhi - DPCC                          326.0   34.760736
# Mundka, Delhi - DPCC                               344.0   58.168605
# NSIT Dwarka, Delhi - CPCB                          412.0   78.679126
# 2023-03-26 08:00:00  b'\xc2\xb5g/m\xc2\xb3'      IN  Delhi
# 2023-03-26 07:00:00  b'\xc2\xb5g/m\xc2\xb3'      IN  Delhi
# ...                                     ...     ...    ...
# 2022-09-26 05:30:00  b'\xc2\xb5g/m\xc2\xb3'      IN  Delhi
# 2022-09-26 05:15:00  b'\xc2\xb5g/m\xc2\xb3'      IN  Delhi
# 2022-09-26 05:15:00  b'\xc2\xb5g/m\xc2\xb3'      IN  Delhi
# 2022-09-26 05:15:00  b'\xc2\xb5g/m\xc2\xb3'      IN  Delhi
# 2022-09-26 05:00:00  b'\xc2\xb5g/m\xc2\xb3'      IN  Delhi
#
#                                      date.utc  coordinates.latitude  \
# date.local
# 2023-03-26 11:00:00 2023-03-26 05:30:00+00:00             28.635760
# 2023-03-26 10:00:00 2023-03-26 04:30:00+00:00             28.635760
# 2023-03-26 09:00:00 2023-03-26 03:30:00+00:00             28.635760
# 2023-03-26 08:00:00 2023-03-26 02:30:00+00:00             28.635760
# 2023-03-26 07:00:00 2023-03-26 01:30:00+00:00             28.635760
# ...                                       ...                   ...
# 2022-09-26 05:30:00 2022-09-26 00:00:00+00:00             28.609090
# 2022-09-26 05:15:00 2022-09-25 23:45:00+00:00             28.628624
# 2022-09-26 05:15:00 2022-09-25 23:45:00+00:00             28.750050
# 2022-09-26 05:15:00 2022-09-25 23:45:00+00:00             28.550425
# 2022-09-26 05:00:00 2022-09-25 23:30:00+00:00             28.635760
#
#                      coordinates.longitude
# date.local
# 2023-03-26 11:00:00              77.224450
# 2023-03-26 10:00:00              77.224450
# 2023-03-26 09:00:00              77.224450
# 2023-03-26 08:00:00              77.224450
# 2023-03-26 07:00:00              77.224450
# ...                                    ...
# 2022-09-26 05:30:00              77.032541
# 2022-09-26 05:15:00              77.241060
# 2022-09-26 05:15:00              77.111261
# 2022-09-26 05:15:00              77.215938
# 2022-09-26 05:00:00              77.224450
#
# [14962 rows x 9 columns]

# %% [markdown]
# ***DATA CRAWLING MEASURMENTS***

# %%
res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14962 entries, 2023-03-26 11:00:00 to 2022-09-26 05:00:00
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   location               14962 non-null  object
#  1   parameter              14962 non-null  object
#  2   value                  14962 non-null  float64
#  3   unit                   14962 non-null  object
#  4   country                14962 non-null  object
#  5   city                   14962 non-null  object
#  6   date.utc               14962 non-null  datetime64[ns, UTC]
#  7   coordinates.latitude   14962 non-null  float64
#  8   coordinates.longitude  14962 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(3), object(5)
# memory usage: 1.1+ MB

# %%
res=res.dropna()

# %%
res.isna().any()
# Out:
# location                 False
# parameter                False
# value                    False
# unit                     False
# country                  False
# city                     False
# date.utc                 False
# coordinates.latitude     False
# coordinates.longitude    False
# dtype: bool

# %%
res.isna().sum()
# Out:
# location                 0
# parameter                0
# value                    0
# unit                     0
# country                  0
# city                     0
# date.utc                 0
# coordinates.latitude     0
# coordinates.longitude    0
# dtype: int64
